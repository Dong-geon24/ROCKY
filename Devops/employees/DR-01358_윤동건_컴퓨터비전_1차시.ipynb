# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# <pre>
# 단축키(괄호는 주피터)
# shift + enter : 셀 실행하고 다음 셀 선택(동일)
# alt + enter : 셀 실행(동일)
# ctrl+m + m : 택스트셀 변환(m)
# ctrl+m + y : 코드셀 변환(y)
# ctrl+m + k : 위셀로 이동(k)
# ctrl+m + j : 아래셀로 이동(j)
# ctrl+m + d : 셀 삭제(d d)
# </pre>

# %%
#나는 왜 버전이 2.15.0이지?
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %% [markdown]
# ##마크다운 문법
# + 쉽다
# + 드라이브 마운트 필수
# 일반 글을 작성하면
# 이어져서 보이게 된다
# 이렇게
# 끝을 네칸 이상 띄우자

# %%
import os
print(os.getcwd())
# Out:
# /content
